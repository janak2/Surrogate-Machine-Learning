# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("G:\\My Drive\\Gdrive\\startup\\Novus Sentry\\data\\Data_v3\\NS_DEV_Test3_Oct2322_1104PM.csv",
    header=2, sep='\t')
N = df.iloc[:,2].argmin()
df = df.iloc[N:,[0,1,2]].reset_index(drop=True)
df.iloc[:,2] /= 100.0
mask = [True] + [df.iloc[i,0] < df.iloc[i+1,0] for i in range(len(df.iloc[:,0]) - 1)]
df = df[mask]
df.iloc[:,0] -= df.iloc[0,0]
df.to_csv("data_no_load.csv", index=False)

# %%
plt.plot(df.iloc[:,0])

# %%
# Out:
# [170, 351, 1465, 1866]
